# %% [markdown]
# ## Lesson 02 — Printing, Strings, Numbers
#
# In this lesson, we will cover how to apply transformations on the basic data types we learned on the previous class. You will find that Python provides a comprehensive library of methods to transform the basic data types.
#
# We will also see some real-world examples on how to apply these concepts to automate the boring tasks.
#
# ### Readings
#
# * Shaw: Exercises 1-10
# * [Python builtin types documentation](https://docs.python.org/3/library/stdtypes.html)
#
# ### Table of Contents
#
# * [Strings](#Strings)
# * [Numbers and Math](#Numbers-and-Math)
# * [Functions](#Defining-a-function)
# * [Getting help](#Getting-help)
# * [Case studies](#Case-studies)

# %% [markdown]
# ### Strings

# %% [markdown]
# With IPython/Jupyter notebooks, we don't have to type `print()` as much as Shaw does in _LPTHW_, but we will use it for this first section.
#
# If you write a standalone script, you will need to use print statements to show the user some output.

# %%
print("This is a sentence.")
# Out:
# This is a sentence.

# %% [markdown]
# In the Jupyter notebook, the **last variable reference without assignment on semicolon is always printed**. You can use this to avoid `print()` statements.

# %%
"This is a sentence."
# Out:
# 'This is a sentence.'

# %% [markdown]
# When creating strings in Python, we tend to stick with double-quotes `"`:

# %%
print("Now the sentence is in double quotes.")
# Out:
# Now the sentence is in double quotes.

# %% [markdown]
# But if you want to use single quotes `'` or double quotes `"` within the text, you can use it without escaping by choosing the string quotation:

# %%
print("Have you heard the word? 'Bird' is the word.")
# Out:
# Have you heard the word? 'Bird' is the word.

# %%
print('Have you heard the word? "Bird" is the word.')
# Out:
# Have you heard the word? "Bird" is the word.

# %% [markdown]
# When you do not have an option, you can use the `\` escape character to display what you need. This also means that to print `\`, you will have to use `\\`:

# %%
print("Here are some more escape characters: ' \" \\ \\\\")
# Out:
# Here are some more escape characters: ' " \ \\

# %% [markdown]
# You can write a multi-line string by using the triple quotes `"""`:

# %%
print(
    """
Here is a block
of text that we
are going to print.
"""
)
# Out:
# Here is a block
# of text that we
# are going to print.

# %% [markdown]
# Or use the `\n` character to input a new line, or `\t` to represent a tab.
#
# **Note:** newline characters vary from system to system, but we conventionally use `\n`. If you want to be strict about it, use `os.linesep`.

# %%
print("\t- One\n\t- Two\n\t- Three")
# Out:
# 	- One
# 	- Two
# 	- Three

# %%
print(
    """	- One
	- Two
	- Three"""
)
# Out:
# 	- One
# 	- Two
# 	- Three

# %% [markdown]
# #### Indexing a string
#
# Strings are sequences of characters, and they have properties like lists. Here, `S` is a variable (with a string assigned to it).

# %%
S = "Spam"

# %%
len(S)
# Out:
# 4

# %%
S[0]
# Out:
# 'S'

# %%
S[0], S[1], S[2], S[3]
# Out:
# ('S', 'p', 'a', 'm')

# %% [markdown]
# We can use comments (starting with a `#`) to add context to what we are typing:

# %%
# Negative indexing the hard way
S[len(S) - 1]
# Out:
# 'm'

# %%
# Last letter
S[-1]
# Out:
# 'm'

# %% [markdown]
# Negative numbers always represent the indexing, in reverse, from the last character (starting at `-1` for the last character):

# %%
S[-1], S[-2], S[-3], S[-4]
# Out:
# ('m', 'a', 'p', 'S')

# %%
# Slice from 1 through 2 (not 3)
S[1:3]
# Out:
# 'pa'

# %%
# Everything but first letter
S[1:]
# Out:
# 'pam'

# %% [markdown]
# Strings are immutable, so their content is never changed by sub-selecting its content:

# %%
# S is not changed
S
# Out:
# 'Spam'

# %%
# Everything but last letter
S[0:-1]
# Out:
# 'Spa'

# %%
# Everything but last letter
S[:-1]
# Out:
# 'Spa'

# %%
# All of S as a top-level copy
S[:]
# Out:
# 'Spam'

# %%
# Then entire sequence, in reverse
S[::-1]
# Out:
# 'mapS'

# %% [markdown]
# ##### To review, we can index a string from the start or from the end:
#
# | Text             | S | p | a | m |
# |------------------|---|---|---|---|
# | index from start | 0 | 1 | 2 | 3 |
# | index from end   |-4 |-3 |-2 |-1 |
#
# This Python-style indexing may seem strange at first, but it has the benefit of not requiring you to know the length of the string you are slicing:
#
# * `S[:2]` gives the **first 2 characters** (regardless of string length)
# * `S[2:]` gives **everything except the first 2 characters** (regardless of string length)
# * `S[-2:]` gives the **last 2 characters** (regardless of string length)
# * `S[:-2]` gives **everything except the last 2 characters** (regardless of string length)

# %%
S[:2], S[2:], S[-2:], S[:-2]
# Out:
# ('Sp', 'am', 'am', 'Sp')

# %%
T = "Donaudampfschiffahrtsgesellschaftskapitän"
T[:2], T[2:], T[-2:], T[:-2]
# Out:
# ('Do',
#  'naudampfschiffahrtsgesellschaftskapitän',
#  'än',
#  'Donaudampfschiffahrtsgesellschaftskapit')

# %% [markdown]
# #### Repetition and concatenation

# %%
# Repetition
S * 8
# Out:
# 'SpamSpamSpamSpamSpamSpamSpamSpam'

# %% [markdown]
# We can concatenate strings with the `+` sign, although it is preferred to use f-strings. Concatenation will always create a new object:

# %%
# Concatenation
S + "xyz"
# Out:
# 'Spamxyz'

# %%
# We prefer using f-strings
f"{S}xyz"
# Out:
# 'Spamxyz'

# %%
# Storing a new value for S, replacing it
S = f"z{S[1:]}"

# %%
# S is now changed
S
# Out:
# 'zpam'

# %% [markdown]
# #### String methods
#
# There are many useful methods to work with strings:

# %%
R = "The quick brown fox jumps over the lazy dog"
R
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %% [markdown]
# Find any sub-string on the original string:

# %%
R.find("fox")
# Out:
# 16

# %% [markdown]
# Notice this method is case sensitive, and will return `-1` when the content was not found:

# %%
R.find("DOG")
# Out:
# -1

# %% [markdown]
# Replace is able to modify a string, and outputs a new modified object:

# %%
R.replace("fox", "cat")
# Out:
# 'The quick brown cat jumps over the lazy dog'

# %% [markdown]
# Some other string helpers can also help you be faster at modifying text:

# %%
R.upper()
# Out:
# 'THE QUICK BROWN FOX JUMPS OVER THE LAZY DOG'

# %%
R.lower()
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %%
R.title()
# Out:
# 'The Quick Brown Fox Jumps Over The Lazy Dog'

# %%
R.count("dog")
# Out:
# 1

# %% [markdown]
# You can chain string operations to save lines of code:

# %%
R.lower().count("the")
# Out:
# 2

# %% [markdown]
# We can convert a string to a list by using the `split()` method, and iterating over the result. Together with the `strip()` method, this is very useful for working with text file parsing:

# %%
line = "aaa,bbb,ccc,ddd"
line
# Out:
# 'aaa,bbb,ccc,ddd'

# %%
line.split(",")
# Out:
# ['aaa', 'bbb', 'ccc', 'ddd']

# %%
line2 = "aaa,bbb,ccc,ddd\n"
line2
# Out:
# 'aaa,bbb,ccc,ddd\n'

# %%
line2.split(",")
# Out:
# ['aaa', 'bbb', 'ccc', 'ddd\n']

# %%
line2 = line2.rstrip()
line2
# Out:
# 'aaa,bbb,ccc,ddd'

# %%
line2.split(",")
# Out:
# ['aaa', 'bbb', 'ccc', 'ddd']

# %%
line3 = "aaa bbb\nccc\tddd"
line3
# Out:
# 'aaa bbb\nccc\tddd'

# %%
line3.split()
# Out:
# ['aaa', 'bbb', 'ccc', 'ddd']

# %%
line4 = "aaa,bbb,ccc,ddd \t \n"
line4
# Out:
# 'aaa,bbb,ccc,ddd \t \n'

# %%
line4.rstrip().split(",")
# Out:
# ['aaa', 'bbb', 'ccc', 'ddd']

# %% [markdown]
# #### String formatters
#
# Formatting strings in Python is very straightforward, and the recommendation is doing it via f-strings (writing an `f` before the string qualifier).

# %%
a = "Bird"
b = "Word"

# %%
# F-strings will allow you to display your results
f"Have you heard? {a} is the {b}."
# Out:
# 'Have you heard? Bird is the Word.'

# %%
f"If we only want one: {a}"
# Out:
# 'If we only want one: Bird'

# %%
f"If we want to display the variable name, use the equal sign: {a=}"
# Out:
# "If we want to display the variable name, use the equal sign: a='Bird'"

# %%
f"We can do operations inside of a f-string. Let's add 2 + 2. It is {2 + 2}."
# Out:
# "We can do operations inside of a f-string. Let's add 2 + 2. It is 4."

# %% [markdown]
# #### But wait, there's more!
#
# There are now three main ways to format strings. See [Real Python](https://realpython.com/python-f-strings/) for more information.

# %% [markdown]
# **Option 1: %-formatting** — Old original Python syntax. This is here as a reference, and you should **avoid using it**.

# %%
"Have you heard? %s is the %s." % (a, b)
# Out:
# 'Have you heard? Bird is the Word.'

# %% [markdown]
# **Option 2: str.format()** – Introduced in Python 2.6. This might still be useful when you need to store a string template to use later, but less relevant since Python 3.14 introduced [Template Strings](https://peps.python.org/pep-0750/).

# %%
"Have you heard? {} is the {}.".format(a, b)
# Out:
# 'Have you heard? Bird is the Word.'

# %%
s = "Have you heard? {} is the {}."
s.format(a, b)
# Out:
# 'Have you heard? Bird is the Word.'

# %%
"Have you heard? {1} is the {0}.".format(a, b)
# Out:
# 'Have you heard? Word is the Bird.'

# %%
"Have you heard? {0} is the {1}.".format(a.upper(), b.upper())
# Out:
# 'Have you heard? BIRD is the WORD.'

# %%
"Have you heard? {animal} is the {thing}.".format(animal=a, thing=b)
# Out:
# 'Have you heard? Bird is the Word.'

# %%
"Have you heard? {animal} is the {thing}.".format(thing=b, animal=a)
# Out:
# 'Have you heard? Bird is the Word.'

# %% [markdown]
# **Option 3: f-strings** – Introduced in Python 3.6. By far the best (and fastest) way to interpolate strings.

# %%
f"Have you heard? {a} is the {b}."
# Out:
# 'Have you heard? Bird is the Word.'

# %%
f"Have you heard? {a.upper()} is the {b.upper()}."
# Out:
# 'Have you heard? BIRD is the WORD.'

# %% [markdown]
# ### Numbers and Math
#
# The order of will of operations be the same as defined in your math class, using parentheses you want to explicitly define what gets evaluated first:

# %%
6 / 2 + 1
# Out:
# 4.0

# %%
6 / (2 + 1)
# Out:
# 2.0

# %% [markdown]
# a, b, c, d, and e are variables (with numbers assigned to them). Use f-strings to print and format them:

# %%
a = 123 + 222
b = 1.5 * 4
c = 2**100
d = 1.0
e = 4

# %%
print(f"a = {a}")
print(f"b = {b}")
print(f"c = {c}")
# Out:
# a = 345
# b = 6.0
# c = 1267650600228229401496703205376

# %%
print(f"1.0 / 4 = {d / e}")
# Out:
# 1.0 / 4 = 0.25

# %%
print(f"1.0 / 4 = {d / e:.1f}")
# Out:
# 1.0 / 4 = 0.2

# %%
print(f"1.0 / 4 = {d / e:.3f}")
# Out:
# 1.0 / 4 = 0.250

# %% [markdown]
# Instead of dividing, you can also get the remainder of a division using the `%` operator:

# %%
# 76 divided by 10 is 7, with remainder 6
76 % 10
# Out:
# 6

# %% [markdown]
# Let's import the `math` module to do more complex operations:

# %%
import math

# %%
math.floor(4.22)
# Out:
# 4

# %%
math.ceil(4.22)
# Out:
# 5

# %%
math.factorial(5)
# Out:
# 120

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(85)
# Out:
# 9.219544457292887

# %% [markdown]
# Here, f-strings can also help you display the results in a more friendly way:

# %%
pi = math.pi
f = math.sqrt(85)
print(f"pi = {pi}")
print(f"math.sqrt(85) = {f:.3f}")
# Out:
# pi = 3.141592653589793
# math.sqrt(85) = 9.220

# %%
print(f"{pi =: }")
print(f"{math.sqrt(85) =: .3f}")
# Out:
# pi = 3.141592653589793
# math.sqrt(85) = 9.220

# %% [markdown]
# Now let's import the `random` module. It contains a wide variety of helpers:

# %%
import random

# %% [markdown]
# The seed will set the internal state of the random library, making your results reproducible.
#
# **Note:** can you say why even AI generates code with seed equals to 42?

# %%
random.seed(42)

# %%
random.random()
# Out:
# 0.6394267984578837

# %%
random.choice([1, 2, 3, 4])
# Out:
# 1

# %%
random.choice(range(10))
# Out:
# 4

# %%
random.seed(42)
g = random.random()
h = random.choice([1, 2, 3, 4])
i = random.choice(range(10))
print(f"random from 0-1: {g:.2f}")
print(f"random from 1,2,3,4: {h}")
print(f"random from 1-10: {i}")
# Out:
# random from 0-1: 0.64
# random from 1,2,3,4: 1
# random from 1-10: 4

# %% [markdown]
# Let's create an 8-ball to answer questions at random:

# %%
magic_8_ball = [
    "It is certain",
    "It is decidedly so",
    "Without a doubt",
    "Yes, definitely",
    "You may rely on it",
    "As I see it, yes",
    "Most likely",
    "Outlook good",
    "Yes",
    "Signs point to yes",
    "Reply hazy try again",
    "Ask again later",
    "Better not tell you now",
    "Cannot predict now",
    "Concentrate and ask again",
    "Don't count on it",
    "My reply is no",
    "My sources say no",
    "Outlook not so good",
    "Very doubtful",
]

# %%
random.choice(magic_8_ball)
# Out:
# 'Outlook good'

# %% [markdown]
# ### Defining a function
#
# Functions abstract logic for re-use later on. **They only run when they are called**.
#
# Python uses indentation (whitespaces or tabs) to structure code in an effort to improve readability of the code.
#
# You can define functions by using the following template format:

# %%
def say_hello():
    print("hello world")


say_hello()
# Out:
# hello world

# %%
def add(a, b):
    """This function adds two numbers together"""
    return a + b

# %%
add(1, 2)
# Out:
# 3

# %% [markdown]
# ### Getting help
#
# Use the question mark or use IPython and tab-complete!

# %%
# get more information about the string variable S
# ?S
# Out:
# Type:        str
# String form: zpam
# Length:      4
# Docstring:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to 'utf-8'.
# errors defaults to 'strict'.

# %%
# get more information about the string find method
# ?S.find
# Out:
# Docstring:
# Return the lowest index in S where substring sub is found, such that sub is contained within S[start:end].
#
# Optional arguments start and end are interpreted as in slice notation.
# Return -1 on failure.
# Type:      builtin_function_or_method

# %%
# get more information about the random seed function
# ?random.seed
# Out:
# Signature: random.seed(a=None, version=2)
# Docstring:
# Initialize internal state from a seed.
#
# The only supported seed types are None, int, float,
# str, bytes, and bytearray.
#
# None or no argument seeds from current time or from an operating
# system specific randomness source if available.
#
# If *a* is an int, all bits are used.
#
# For version 2 (the default), all of the bits are used if *a* is a str,
# bytes, or bytearray.  For version 1 (provided for reproducing random
# sequences from older versions of Python), the algorithm for str and
# bytes generates a narrower range of seeds.
# File:      /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/random.py
# Type:      method

# %%
# try getting documentation on our own add function
# ?add
# Out:
# Signature: add(a, b)
# Docstring: This function adds two numbers together
# File:      /var/folders/wf/l1cgt65d4yj59p5x0xd9t7500000gn/T/ipykernel_70659/2971324843.py
# Type:      function

# %%
# try typing `S.` then Tab below to see which methods this string has

# %%
# try typing `math.` then Tab below to see what methods/functions math has

# %%
# list all the variables in the workspace
# %whos
# Out:
# Variable       Type        Data/Info
# ------------------------------------
# R              str         The quick brown fox jumps over the lazy dog
# S              str         zpam
# T              str         Donaudampfschiffahrtsgesellschaftskapitän
# a              int         345
# add            function    <function add at 0x10d1ac510>
# b              float       6.0
# c              int         1267650600228229401496703205376
# d              float       1.0
# e              int         4
# f              float       9.219544457292887
# g              float       0.6394267984578837
# h              int         1
# i              int         4
# line           str         aaa,bbb,ccc,ddd
# line2          str         aaa,bbb,ccc,ddd
# line3          str         aaa bbb\nccc	ddd
# line4          str         aaa,bbb,ccc,ddd 	 \n
# magic_8_ball   list        n=20
# math           module      <module 'math' from '/opt<...>h.cpython-314-darwin.so'>
# ...

# %% [markdown]
# ### Case studies
#
# Let's put this class content to practice with some real-world examples.

# %% [markdown]
# #### Password generator
#
# We will build a password generator from scratch, using only Python's standard library.
#
# We do not have to create a list of valid characters, Python already has it on the `string` module

# %%
import string

# %%
print(string.ascii_lowercase)
print(string.ascii_uppercase)
print(string.ascii_letters)
print(string.digits)
print(string.punctuation)
# Out:
# abcdefghijklmnopqrstuvwxyz
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# To build a password we would have to add all strings to a single sequence to pick from:

# %%
all_characters = string.ascii_letters + string.digits + string.punctuation
all_characters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# Then build a string based on the results:

# %%
password = ""
for i in range(16):
    password = password + random.choice(all_characters)
print(password)
# Out:
# Crn](l.2edlBD#:d

# %% [markdown]
# We can wrap it in a function to make generation easier:

# %%
def generate_password(length, use_special_characters=False):
    characters = string.ascii_letters + string.digits
    if use_special_characters:
        characters += string.punctuation
    password = ""
    for i in range(length):
        password = password + random.choice(characters)
    return password

# %%
generate_password(10)
# Out:
# 'JmTPSIAoCL'

# %%
generate_password(12)
# Out:
# 'rZ3aWZkSBvrj'

# %%
generate_password(12, True)
# Out:
# 'BRnlWmTS:Hf~'

# %% [markdown]
# #### Email list sanitizer
#
# We have received a raw dump of email addresses from a signup form — duplicates, extra spaces, mixed case, some broken. You need a clean list and want to extract the person's name and company from each email.
#
# **Note**: these names were generated at random. Sorry if this is your real email.

# %%
raw_emails = """
    John.Smith@NovaTech.COM
   JANE.DOE@greenleaf.com
     anna.maria.mueller @SkywardInc.de
  john.smith@novatech.com
    MAX.WEBER@GreenLeaf.com
    li.na.braun@BLUEOCEAN.de
     jane.doe@greenleaf.com
  peter.  gross@novatech.com
   TOM.JONES@blueocean.de
    JOHN.SMITH@NOVATECH.COM
  lisa.braun @skywardinc.de
  karl.heinz.schmidt@GREENLEAF.COM
    felix.lang@BlueOcean.de
    maria.klein @SkywardInc.de
  STEFAN.ROTH@novatech.com
     eva.wagner @greenleaf.com
"""

# %% [markdown]
# Split the lines into individual entries, then work into cleaning each individual one:

# %%
lines = raw_emails.strip().split("\n")
lines
# Out:
# ['John.Smith@NovaTech.COM',
#  '   JANE.DOE@greenleaf.com',
#  '     anna.maria.mueller @SkywardInc.de',
#  '  john.smith@novatech.com',
#  '    MAX.WEBER@GreenLeaf.com',
#  '    li.na.braun@BLUEOCEAN.de',
#  '     jane.doe@greenleaf.com',
#  '  peter.  gross@novatech.com',
#  '   TOM.JONES@blueocean.de',
#  '    JOHN.SMITH@NOVATECH.COM',
#  '  lisa.braun @skywardinc.de',
#  '  karl.heinz.schmidt@GREENLEAF.COM',
#  '    felix.lang@BlueOcean.de',
#  '    maria.klein @SkywardInc.de',
#  '  STEFAN.ROTH@novatech.com',
#  '     eva.wagner @greenleaf.com']

# %% [markdown]
# We will start working on a single entry first to figure out what operations we need:

# %%
person = lines[2]
person
# Out:
# '     anna.maria.mueller @SkywardInc.de'

# %% [markdown]
# Emails have no spaces and are case insensitive, so let's standardize them:

# %%
email = person.strip().replace(" ", "").lower()
email
# Out:
# 'anna.maria.mueller@skywardinc.de'

# %% [markdown]
# We can now use `partition`, a variation of `split`, to separate the person name from domain name:

# %%
name, _, domain_name = email.partition("@")
name, domain_name
# Out:
# ('anna.maria.mueller', 'skywardinc.de')

# %% [markdown]
# Let's replace dots with spaces and use the `title` function to get the full name:

# %%
full_name = name.replace(".", " ").title()
full_name
# Out:
# 'Anna Maria Mueller'

# %%
company_name = domain_name.split(".")[0].capitalize()
company_name
# Out:
# 'Skywardinc'

# %% [markdown]
# We can bring it all together in a single function:

# %%
def transform(line):
    email = line.strip().replace(" ", "").lower()
    name, _, domain_name = email.partition("@")
    full_name = name.replace(".", " ").title()
    company_name = domain_name.split(".")[0].capitalize()
    return full_name, company_name, email

# %%
transform(lines[0])
# Out:
# ('John Smith', 'Novatech', 'john.smith@novatech.com')

# %% [markdown]
# Apply to all entries using a loop:

# %%
for line in lines:
    full_name, company_name, email = transform(line)
    print(f"{full_name=}, {company_name=}, {email=}")
# Out:
# full_name='John Smith', company_name='Novatech', email='john.smith@novatech.com'
# full_name='Jane Doe', company_name='Greenleaf', email='jane.doe@greenleaf.com'
# full_name='Anna Maria Mueller', company_name='Skywardinc', email='anna.maria.mueller@skywardinc.de'
# full_name='John Smith', company_name='Novatech', email='john.smith@novatech.com'
# full_name='Max Weber', company_name='Greenleaf', email='max.weber@greenleaf.com'
# full_name='Li Na Braun', company_name='Blueocean', email='li.na.braun@blueocean.de'
# full_name='Jane Doe', company_name='Greenleaf', email='jane.doe@greenleaf.com'
# full_name='Peter Gross', company_name='Novatech', email='peter.gross@novatech.com'
# full_name='Tom Jones', company_name='Blueocean', email='tom.jones@blueocean.de'
# full_name='John Smith', company_name='Novatech', email='john.smith@novatech.com'
# full_name='Lisa Braun', company_name='Skywardinc', email='lisa.braun@skywardinc.de'
# ...
